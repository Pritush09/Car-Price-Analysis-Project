# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('Car details v3.csv')

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 8123  False  False          False      False  False        False
# 8124  False  False          False      False  False        False
# 8125  False  False          False      False  False        False
# 8126  False  False          False      False  False        False
# 8127  False  False          False      False  False        False
#
#       transmission  owner  mileage  engine  max_power  torque  seats
# 0            False  False    False   False      False   False  False
# ...

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.mileage
# Out:
# 0        23.4 kmpl
# 1       21.14 kmpl
# 2        17.7 kmpl
# 3        23.0 kmpl
# 4        16.1 kmpl
#            ...
# 8123     18.5 kmpl
# 8124     16.8 kmpl
# 8125     19.3 kmpl
# 8126    23.57 kmpl
# 8127    23.57 kmpl
# Name: mileage, Length: 8128, dtype: object

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
Finaldata = df[['year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
       'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
       'seats']]

# %%
Finaldata['Current_year']=2020

# %%
Finaldata.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
#
#           owner     mileage   engine   max_power                    torque  \
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp            190Nm@ 2000rpm
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm
# 2   Third Owner   17.7 kmpl  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)
# 3   First Owner   23.0 kmpl  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm
# 4   First Owner   16.1 kmpl  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)
#
#    seats  Current_year
# 0    5.0          2020
# 1    5.0          2020
# 2    5.0          2020
# ...

# %%
Finaldata.year.unique()
# Out:
# array([2014, 2006, 2010, 2007, 2017, 2001, 2011, 2013, 2005, 2009, 2016,
#        2012, 2002, 2015, 2018, 2003, 2019, 2008, 2020, 1999, 2000, 1983,
#        2004, 1996, 1994, 1995, 1998, 1997, 1991], dtype=int64)

# %%
Finaldata.isnull().sum()
# Out:
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# Current_year       0
# dtype: int64

# %%
Finaldata.dropna(how='any',inplace=True)

# %%
Finaldata.shape
# Out:
# (7906, 13)

# %%
Finaldata['No_of_Year'] = Finaldata['Current_year'] - Finaldata['year']

# %%
Finaldata[Finaldata.No_of_Year>15]
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 7     2001          45000       5000  Petrol  Individual       Manual
# 18    2002         150000      80000  Petrol  Individual       Manual
# 177   1999          40000      40000  Petrol  Individual       Manual
# 186   2000         100000      60000  Petrol  Individual       Manual
# 328   2003          65000      60000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 7999  2004         100000      40000  Petrol  Individual       Manual
# 8025  1998          35000      40000  Petrol  Individual       Manual
# 8042  1997         300000     186388  Petrol  Individual       Manual
# 8105  2004         135000     120000  Petrol  Individual       Manual
# 8115  1997          40000     120000  Petrol  Individual       Manual
#
#                      owner    mileage   engine max_power            torque  \
# ...

# %%
Finaldata.drop(columns='year',axis=1,inplace=True)

# %%
Finaldata.drop(columns=['Current_year','torque'],axis=1,inplace=True)

# %%
Finaldata.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#       mileage   engine   max_power  seats  No_of_Year
# 0   23.4 kmpl  1248 CC      74 bhp    5.0           6
# 1  21.14 kmpl  1498 CC  103.52 bhp    5.0           6
# 2   17.7 kmpl  1497 CC      78 bhp    5.0          14
# 3   23.0 kmpl  1396 CC      90 bhp    5.0          10
# 4   16.1 kmpl  1298 CC    88.2 bhp    5.0          13

# %%
Finaldata.corr()
# Out:
#                selling_price  km_driven     seats  No_of_Year
# selling_price       1.000000  -0.222158  0.041617   -0.412302
# km_driven          -0.222158   1.000000  0.227259    0.428548
# seats               0.041617   0.227259  1.000000    0.007923
# No_of_Year         -0.412302   0.428548  0.007923    1.000000

# %%
Finaldata['mileage']=Finaldata.mileage.str.replace('kmpl','')
Finaldata['mileage']=Finaldata.mileage.str.replace(' ','')
Finaldata['mileage']=Finaldata.mileage.str.replace('km/kg','')

# %%
Finaldata.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#   mileage   engine   max_power  seats  No_of_Year
# 0    23.4  1248 CC      74 bhp    5.0           6
# 1   21.14  1498 CC  103.52 bhp    5.0           6
# 2    17.7  1497 CC      78 bhp    5.0          14
# 3    23.0  1396 CC      90 bhp    5.0          10
# 4    16.1  1298 CC    88.2 bhp    5.0          13

# %%
Finaldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   selling_price  7906 non-null   int64
#  1   km_driven      7906 non-null   int64
#  2   fuel           7906 non-null   object
#  3   seller_type    7906 non-null   object
#  4   transmission   7906 non-null   object
#  5   owner          7906 non-null   object
#  6   mileage        7906 non-null   object
#  7   engine         7906 non-null   object
#  8   max_power      7906 non-null   object
#  9   seats          7906 non-null   float64
#  10  No_of_Year     7906 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 741.2+ KB

# %%
Finaldata['mileage']=Finaldata['mileage'].astype(float)

# %%
column1 = Finaldata['mileage']
column2 = Finaldata['selling_price']
column1.corr(column2)
# Mileage ham nahi lenge
# Out:
# -0.12627994951355337

# %%
Finaldata['max_power']=Finaldata.max_power.str.replace(" bhp","")

# %%
Finaldata['max_power']=Finaldata['max_power'].astype(float)

# %%
Finaldata['max_power'].corr(Finaldata['selling_price'])# bahut zayada correlated he
# Out:
# 0.7496737800444904

# %%
Finaldata['engine']=Finaldata.engine.str.replace(" CC","")

# %%
Finaldata['engine']=Finaldata['engine'].astype(int)

# %%
Finaldata.corr()# ye choro niche wala dekho
# Out:
#                selling_price  km_driven   mileage    engine  max_power  \
# selling_price       1.000000  -0.222158 -0.126280  0.455682   0.749674
# km_driven          -0.222158   1.000000 -0.172980  0.206031  -0.038159
# mileage            -0.126280  -0.172980  1.000000 -0.576408  -0.374621
# engine              0.455682   0.206031 -0.576408  1.000000   0.703975
# max_power           0.749674  -0.038159 -0.374621  0.703975   1.000000
# seats               0.041617   0.227259 -0.451700  0.611103   0.191999
# No_of_Year         -0.412302   0.428548 -0.328544 -0.018263  -0.226598
#
#                   seats  No_of_Year
# selling_price  0.041617   -0.412302
# km_driven      0.227259    0.428548
# mileage       -0.451700   -0.328544
# engine         0.611103   -0.018263
# max_power      0.191999   -0.226598
# seats          1.000000    0.007923
# No_of_Year     0.007923    1.000000

# %%
sns.heatmap(Finaldata.corr(),annot=True) # utna acha nahi he
# Out:
# <AxesSubplot:>

# %%
Finaldata.seller_type.unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
Finaldata.fuel.unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
Finaldata.owner.unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner'], dtype=object)

# %%
Finaldata.transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
pd.options.display.max_seq_items=200

# %%
Finaldata[Finaldata['owner']=='Fourth & Above Owner'].index
# Out:
# Int64Index([ 123,  126,  275,  327,  328,  333,  337,  338,  359,  367,  563,
#              582,  690,  691,  740,  760,  762,  770,  775,  808,  818,  852,
#              889,  898, 1004, 1025, 1027, 1245, 1263, 1265, 1354, 1361, 1415,
#             1479, 1525, 1535, 1555, 1614, 1665, 1760, 1782, 1786, 1852, 1882,
#             1889, 1890, 1892, 1967, 2055, 2100, 2114, 2122, 2166, 2180, 2241,
#             2304, 2340, 2350, 2430, 2439, 2928, 2933, 3046, 3060, 3119, 3120,
#             3224, 3291, 3314, 3317, 3321, 3326, 3458, 3494, 3593, 3594, 3718,
#             3797, 3798, 3805, 3809, 3829, 3988, 4013, 4105, 4112, 4116, 4165,
#             4176, 4184, 4354, 4374, 4570, 4602, 4626, 4631, 4752, 4841, 4847,
#             4848, 4911, 5029, 5082, 5150, 5193, 5207, 5302, 5316, 5317, 5387,
#             5462, 5466, 5535, 5536, 5540, 5552, 5561, 5598, 5681, 5698, 5726,
#             5744, 5759, 5885, 5965, 6195, 6381, 6461, 6611, 6623, 6685, 6711,
# ...

# %%
Finaldata.drop(index = [4383,4950,4951,4952,6220],inplace=True)

# %%
Finaldata.drop(index=[ 123,  126,  275,  327,  328,  333,  337,  338,  359,  367,  563,
             582,  690,  691,  740,  760,  762,  770,  775,  808,  818,  852,
             889,  898, 1004, 1025, 1027, 1245, 1263, 1265, 1354, 1361, 1415,
            1479, 1525, 1535, 1555, 1614, 1665, 1760, 1782, 1786, 1852, 1882,
            1889, 1890, 1892, 1967, 2055, 2100, 2114, 2122, 2166, 2180, 2241,
            2304, 2340, 2350, 2430, 2439, 2928, 2933, 3046, 3060, 3119, 3120,
            3224, 3291, 3314, 3317, 3321, 3326, 3458, 3494, 3593, 3594, 3718,
            3797, 3798, 3805, 3809, 3829, 3988, 4013, 4105, 4112, 4116, 4165,
            4176, 4184, 4354, 4374, 4570, 4602, 4626, 4631, 4752, 4841, 4847,
            4848, 4911, 5029, 5082, 5150, 5193, 5207, 5302, 5316, 5317, 5387,
            5462, 5466, 5535, 5536, 5540, 5552, 5561, 5598, 5681, 5698, 5726,
            5744, 5759, 5885, 5965, 6195, 6381, 6461, 6611, 6623, 6685, 6711,
            6738, 6824, 6825, 6857, 6919, 6920, 6935, 7064, 7111, 7141, 7197,
            7453, 7468, 7584, 7632, 7633, 7693, 7729, 7741, 7818, 7886, 7905,
            7913, 7916, 8017, 8041, 8067, 8124],inplace=True)

# %%
Finaldata.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats  No_of_Year
# 0    23.40    1248      74.00    5.0           6
# 1    21.14    1498     103.52    5.0           6
# 2    17.70    1497      78.00    5.0          14
# 3    23.00    1396      90.00    5.0          10
# 4    16.10    1298      88.20    5.0          13

# %%
Finaldata = pd.get_dummies(Finaldata,drop_first=True)

# %%
Finaldata.head()
# Out:
#    selling_price  km_driven  mileage  engine  max_power  seats  No_of_Year  \
# 0         450000     145500    23.40    1248      74.00    5.0           6
# 1         370000     120000    21.14    1498     103.52    5.0           6
# 2         158000     140000    17.70    1497      78.00    5.0          14
# 3         225000     127000    23.00    1396      90.00    5.0          10
# 4         130000     120000    16.10    1298      88.20    5.0          13
#
#    fuel_Diesel  fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0            1         0            0                       1
# 1            1         0            0                       1
# 2            0         0            1                       1
# 3            1         0            0                       1
# 4            0         0            1                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  owner_Second Owner  \
# ...

# %%
corrmat = Finaldata.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
# plot heat map 
g = sns.heatmap(Finaldata[top_corr_features].corr(),annot=True,cmap='RdYlGn')
